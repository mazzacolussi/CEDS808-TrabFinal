# %%
import os
import pandas as pd
import yaml

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
features_config = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'feature_config.yaml'), "r"))

# %%
df_train = pd.read_csv(os.path.join('..', 'data', 'train_test', 'train.csv'))

print(df_train.shape)
df_train.head()
# Out:
# (32940, 25)
#    age           job  marital            education  default housing loan  \
# 0   31        admin.   single    university.degree       no      no   no
# 1   39     housemaid  married          high.school       no     yes   no
# 2   34  entrepreneur  married  professional.course       no     yes   no
# 3   36    technician  married             basic.9y  unknown      no   no
# 4   25       student   single              unknown  unknown     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0   cellular   sep         fri       123         3    999         0
# 1  telephone   may         fri        61         2    999         0
# 2   cellular   jul         thu       109         4    999         0
# 3  telephone   may         tue       109         9    999         0
# 4   cellular   aug         fri        50         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent          -3.4          92.379          -29.8      0.803
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.4          93.918          -42.7      4.958
# 3  nonexistent           1.1          93.994          -36.4      4.856
# 4  nonexistent          -2.9          92.201          -31.4      0.825
#
#    nr.employed quarter  contacts_tendency employment_status  \
# 0       5017.5      3Q                0.0          employed
# 1       5191.0      2Q                0.0          employed
# 2       5228.1      3Q                0.0          employed
# 3       5191.0      2Q                0.0          employed
# 4       5076.2      3Q                0.0      not_employed
#
#    was_contacted_before  y
# 0                 False  0
# 1                 False  0
# 2                 False  0
# 3                 False  0
# 4                 False  0

# %%
df_train.y.mean()
# Out:
# 0.11214329083181543

# %%
df_test = pd.read_csv(os.path.join('..', 'data', 'train_test', 'test.csv'))

print(df_test.shape)
df_test.head()
# Out:
# (8236, 25)
#    age          job   marital            education  default housing loan  \
# 0   27      student    single          high.school  unknown     yes   no
# 1   60       admin.  divorced  professional.course       no     yes   no
# 2   51  blue-collar   married          high.school       no      no   no
# 3   39  blue-collar    single              unknown  unknown      no   no
# 4   35  blue-collar   married             basic.9y  unknown      no   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   may         thu        38         9    999         0
# 1   cellular   sep         wed       481         1    999         1
# 2  telephone   may         fri       147         1    999         0
# 3  telephone   may         mon       168         1    999         0
# 4  telephone   may         fri       288         3    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.860
# 1      failure          -1.1          94.199          -37.5      0.886
# 2  nonexistent           1.1          93.994          -36.4      4.855
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.864
#
#    nr.employed quarter  contacts_tendency employment_status  \
# 0       5191.0      2Q                0.0      not_employed
# 1       4963.6      3Q                1.0          employed
# 2       5191.0      2Q                0.0          employed
# 3       5191.0      2Q                0.0          employed
# 4       5191.0      2Q                0.0          employed
#
#    was_contacted_before  y
# 0                 False  0
# 1                 False  1
# 2                 False  0
# 3                 False  0
# 4                 False  0

# %%
df_test.y.mean()
# Out:
# 0.11474016512870325
