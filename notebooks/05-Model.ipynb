# %%
import os
import pandas as pd
import yaml
import pickle

from utils.training_utils import find_specific_variables

from lightgbm import LGBMClassifier

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
features = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'feature_config.yaml'), 'r'))

# %% [markdown]
# # Modelo para classificação de um produto em promoção

# %%
df = pd.read_csv(os.path.join('..', 'data', 'train_test', 'train_encoded.csv'))

print(df.shape)
df.head()
# Out:
# (32940, 19)
#    contact  default  education  job  month  poutcome  quarter   age  campaign  \
# 0      0.0      0.0        6.0  0.0    9.0       1.0      2.0  31.0       3.0
# 1      1.0      0.0        3.0  3.0    6.0       1.0      1.0  39.0       2.0
# 2      0.0      0.0        5.0  2.0    3.0       1.0      2.0  34.0       4.0
# 3      1.0      1.0        2.0  9.0    6.0       1.0      1.0  36.0       9.0
# 4      0.0      1.0        7.0  8.0    1.0       1.0      2.0  25.0       1.0
#
#    cons.conf.idx  cons.price.idx  contacts_tendency  emp.var.rate  euribor3m  \
# 0          -29.8          92.379                0.0          -3.4      0.803
# 1          -36.4          93.994                0.0           1.1      4.857
# 2          -42.7          93.918                0.0           1.4      4.958
# 3          -36.4          93.994                0.0           1.1      4.856
# 4          -31.4          92.201                0.0          -2.9      0.825
#
#    nr.employed  pdays  previous  was_contacted_before  y
# 0       5017.5  999.0       0.0                   0.0  0
# 1       5191.0  999.0       0.0                   0.0  0
# 2       5228.1  999.0       0.0                   0.0  0
# 3       5191.0  999.0       0.0                   0.0  0
# 4       5076.2  999.0       0.0                   0.0  0

# %%
seletor = pickle.load(
    open(os.path.join('..', 'models', 'encoders', 'seletor_2.pkl'), 'rb')
)

df_hyperparams = pickle.load(
    open(os.path.join('..', 'models', 'df_metrics_results_tunning_lgbm.pkl'), 'rb')
)

# %%
feature_target = find_specific_variables(features, 'target', specific_value=True)

# %%
df_treino, df_valid = train_test_split(df, test_size=0.2, random_state=96)

# %%
print(f'Shape Treino: {df_treino.shape}')
print(f'Shape Valid: {df_valid.shape}')
# Out:
# Shape Treino: (26352, 19)
# Shape Valid: (6588, 19)

# %%
print(f'% Treino: {df_treino[feature_target[0]].mean()}')
print(f'% Valid: {df_valid[feature_target[0]].mean()}')
# Out:
# % Treino: 0.11202185792349727
# % Valid: 0.11262902246508803

# %%
df_hyperparams[df_hyperparams.value == max(df_hyperparams.value)].T
# Out:
#                                                   22
# number                                            22
# value                                       0.807497
# datetime_start            2025-06-21 15:13:34.908668
# datetime_complete         2025-06-21 15:13:37.438271
# duration                      0 days 00:00:02.529603
# params_class_weight                         balanced
# params_learning_rate                        0.016298
# params_max_depth                                   6
# params_min_child_samples                          79
# params_n_estimators                              219
# params_num_leaves                                 44
# state                                       COMPLETE

# %%
best_row = df_hyperparams.loc[df_hyperparams['value'].idxmax()]
best_params = best_row.filter(like='params_')
hyper_params = {col.replace('params_', ''): best_params[col] for col in best_params.index}


hyper_params.update({
    'eval_metric': 'auc',
})

# %%
hyper_params
# Out:
# {'class_weight': 'balanced',
#  'learning_rate': 0.01629792783423414,
#  'max_depth': 6,
#  'min_child_samples': 79,
#  'n_estimators': 219,
#  'num_leaves': 44,
#  'eval_metric': 'auc'}

# %%
model = LGBMClassifier(
    **hyper_params,
    random_state=12,
    n_jobs=-1
)

model
# Out:
# LGBMClassifier(class_weight='balanced', eval_metric='auc',
#                learning_rate=0.01629792783423414, max_depth=6,
#                min_child_samples=79, n_estimators=219, num_leaves=44,
#                random_state=12)

# %%
model.fit(
    df_treino[seletor.features].values,
    df_treino[feature_target].values,
    eval_set=[(df_valid[seletor.features].values, df_valid[feature_target].values)],
    verbose=True
)
# Out:
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [1]	valid_0's binary_logloss: 0.688284
# [2]	valid_0's binary_logloss: 0.683574
# [3]	valid_0's binary_logloss: 0.678983
# [4]	valid_0's binary_logloss: 0.67454
# [5]	valid_0's binary_logloss: 0.670211
# [6]	valid_0's binary_logloss: 0.665997
# [7]	valid_0's binary_logloss: 0.661902
# [8]	valid_0's binary_logloss: 0.657918
# [9]	valid_0's binary_logloss: 0.654053
# [10]	valid_0's binary_logloss: 0.650291
# [11]	valid_0's binary_logloss: 0.646606
# [12]	valid_0's binary_logloss: 0.643051
# [13]	valid_0's binary_logloss: 0.639572
# [14]	valid_0's binary_logloss: 0.636185
# [15]	valid_0's binary_logloss: 0.63291
# [16]	valid_0's binary_logloss: 0.629706
# [17]	valid_0's binary_logloss: 0.626607
# [18]	valid_0's binary_logloss: 0.623576
# [19]	valid_0's binary_logloss: 0.620628
# [20]	valid_0's binary_logloss: 0.617702
# [21]	valid_0's binary_logloss: 0.614897
# [22]	valid_0's binary_logloss: 0.61218
# [23]	valid_0's binary_logloss: 0.609527
# [24]	valid_0's binary_logloss: 0.606961
# [25]	valid_0's binary_logloss: 0.604414
# [26]	valid_0's binary_logloss: 0.601952
# [27]	valid_0's binary_logloss: 0.599541
# [28]	valid_0's binary_logloss: 0.597195
# [29]	valid_0's binary_logloss: 0.594881
# [30]	valid_0's binary_logloss: 0.592656
# [31]	valid_0's binary_logloss: 0.590526
# [32]	valid_0's binary_logloss: 0.588372
# [33]	valid_0's binary_logloss: 0.586349
# [34]	valid_0's binary_logloss: 0.584321
# [35]	valid_0's binary_logloss: 0.582395
# [36]	valid_0's binary_logloss: 0.580471
# [37]	valid_0's binary_logloss: 0.578591
# [38]	valid_0's binary_logloss: 0.576796
# [39]	valid_0's binary_logloss: 0.575025
# [40]	valid_0's binary_logloss: 0.57325
# [41]	valid_0's binary_logloss: 0.571605
# [42]	valid_0's binary_logloss: 0.569953
# [43]	valid_0's binary_logloss: 0.568297
# [44]	valid_0's binary_logloss: 0.566733
# [45]	valid_0's binary_logloss: 0.56522
# [46]	valid_0's binary_logloss: 0.563706
# [47]	valid_0's binary_logloss: 0.562261
# [48]	valid_0's binary_logloss: 0.560821
# [49]	valid_0's binary_logloss: 0.559482
# [50]	valid_0's binary_logloss: 0.558118
# [51]	valid_0's binary_logloss: 0.556797
# [52]	valid_0's binary_logloss: 0.555561
# [53]	valid_0's binary_logloss: 0.554302
# [54]	valid_0's binary_logloss: 0.553102
# [55]	valid_0's binary_logloss: 0.551923
# [56]	valid_0's binary_logloss: 0.550751
# [57]	valid_0's binary_logloss: 0.54964
# [58]	valid_0's binary_logloss: 0.548549
# [59]	valid_0's binary_logloss: 0.547462
# [60]	valid_0's binary_logloss: 0.546379
# [61]	valid_0's binary_logloss: 0.545337
# [62]	valid_0's binary_logloss: 0.54432
# [63]	valid_0's binary_logloss: 0.543324
# [64]	valid_0's binary_logloss: 0.542359
# [65]	valid_0's binary_logloss: 0.54143
# [66]	valid_0's binary_logloss: 0.540522
# [67]	valid_0's binary_logloss: 0.539598
# [68]	valid_0's binary_logloss: 0.538708
# [69]	valid_0's binary_logloss: 0.537829
# [70]	valid_0's binary_logloss: 0.536941
# [71]	valid_0's binary_logloss: 0.53611
# [72]	valid_0's binary_logloss: 0.535256
# [73]	valid_0's binary_logloss: 0.534434
# [74]	valid_0's binary_logloss: 0.533654
# [75]	valid_0's binary_logloss: 0.532886
# [76]	valid_0's binary_logloss: 0.532127
# [77]	valid_0's binary_logloss: 0.531412
# [78]	valid_0's binary_logloss: 0.530702
# [79]	valid_0's binary_logloss: 0.530009
# [80]	valid_0's binary_logloss: 0.529358
# [81]	valid_0's binary_logloss: 0.528668
# [82]	valid_0's binary_logloss: 0.527981
# [83]	valid_0's binary_logloss: 0.527376
# [84]	valid_0's binary_logloss: 0.526741
# [85]	valid_0's binary_logloss: 0.526126
# [86]	valid_0's binary_logloss: 0.525551
# [87]	valid_0's binary_logloss: 0.525011
# [88]	valid_0's binary_logloss: 0.524431
# [89]	valid_0's binary_logloss: 0.52387
# [90]	valid_0's binary_logloss: 0.523376
# [91]	valid_0's binary_logloss: 0.522827
# [92]	valid_0's binary_logloss: 0.522337
# [93]	valid_0's binary_logloss: 0.521875
# [94]	valid_0's binary_logloss: 0.521363
# [95]	valid_0's binary_logloss: 0.520876
# [96]	valid_0's binary_logloss: 0.520446
# [97]	valid_0's binary_logloss: 0.51997
# [98]	valid_0's binary_logloss: 0.51957
# [99]	valid_0's binary_logloss: 0.519131
# [100]	valid_0's binary_logloss: 0.51873
# [101]	valid_0's binary_logloss: 0.518345
# [102]	valid_0's binary_logloss: 0.517864
# [103]	valid_0's binary_logloss: 0.517458
# [104]	valid_0's binary_logloss: 0.517041
# [105]	valid_0's binary_logloss: 0.516591
# [106]	valid_0's binary_logloss: 0.516231
# [107]	valid_0's binary_logloss: 0.515873
# [108]	valid_0's binary_logloss: 0.515499
# [109]	valid_0's binary_logloss: 0.51509
# [110]	valid_0's binary_logloss: 0.514749
# [111]	valid_0's binary_logloss: 0.51437
# [112]	valid_0's binary_logloss: 0.514001
# [113]	valid_0's binary_logloss: 0.513664
# [114]	valid_0's binary_logloss: 0.513323
# [115]	valid_0's binary_logloss: 0.512972
# [116]	valid_0's binary_logloss: 0.512649
# [117]	valid_0's binary_logloss: 0.512378
# [118]	valid_0's binary_logloss: 0.512113
# [119]	valid_0's binary_logloss: 0.511768
# [120]	valid_0's binary_logloss: 0.511519
# [121]	valid_0's binary_logloss: 0.511279
# [122]	valid_0's binary_logloss: 0.510972
# [123]	valid_0's binary_logloss: 0.510676
# [124]	valid_0's binary_logloss: 0.510466
# [125]	valid_0's binary_logloss: 0.510231
# [126]	valid_0's binary_logloss: 0.50995
# [127]	valid_0's binary_logloss: 0.509716
# [128]	valid_0's binary_logloss: 0.509473
# [129]	valid_0's binary_logloss: 0.509235
# [130]	valid_0's binary_logloss: 0.50903
# [131]	valid_0's binary_logloss: 0.508802
# [132]	valid_0's binary_logloss: 0.508621
# [133]	valid_0's binary_logloss: 0.508388
# [134]	valid_0's binary_logloss: 0.508211
# [135]	valid_0's binary_logloss: 0.507989
# [136]	valid_0's binary_logloss: 0.50776
# [137]	valid_0's binary_logloss: 0.507542
# [138]	valid_0's binary_logloss: 0.507352
# [139]	valid_0's binary_logloss: 0.507143
# [140]	valid_0's binary_logloss: 0.506944
# [141]	valid_0's binary_logloss: 0.506759
# [142]	valid_0's binary_logloss: 0.50663
# [143]	valid_0's binary_logloss: 0.50641
# [144]	valid_0's binary_logloss: 0.506263
# [145]	valid_0's binary_logloss: 0.506087
# [146]	valid_0's binary_logloss: 0.505898
# [147]	valid_0's binary_logloss: 0.505718
# [148]	valid_0's binary_logloss: 0.505555
# [149]	valid_0's binary_logloss: 0.505363
# [150]	valid_0's binary_logloss: 0.505235
# [151]	valid_0's binary_logloss: 0.505089
# [152]	valid_0's binary_logloss: 0.504965
# [153]	valid_0's binary_logloss: 0.504828
# [154]	valid_0's binary_logloss: 0.504716
# [155]	valid_0's binary_logloss: 0.504598
# [156]	valid_0's binary_logloss: 0.504477
# [157]	valid_0's binary_logloss: 0.504371
# [158]	valid_0's binary_logloss: 0.504248
# [159]	valid_0's binary_logloss: 0.504138
# [160]	valid_0's binary_logloss: 0.504023
# [161]	valid_0's binary_logloss: 0.503918
# [162]	valid_0's binary_logloss: 0.503829
# [163]	valid_0's binary_logloss: 0.503714
# [164]	valid_0's binary_logloss: 0.503602
# [165]	valid_0's binary_logloss: 0.503468
# [166]	valid_0's binary_logloss: 0.503369
# [167]	valid_0's binary_logloss: 0.50326
# [168]	valid_0's binary_logloss: 0.503166
# [169]	valid_0's binary_logloss: 0.503089
# [170]	valid_0's binary_logloss: 0.503011
# [171]	valid_0's binary_logloss: 0.502908
# [172]	valid_0's binary_logloss: 0.502837
# [173]	valid_0's binary_logloss: 0.502732
# [174]	valid_0's binary_logloss: 0.502652
# [175]	valid_0's binary_logloss: 0.502578
# [176]	valid_0's binary_logloss: 0.502489
# [177]	valid_0's binary_logloss: 0.502402
# [178]	valid_0's binary_logloss: 0.502326
# [179]	valid_0's binary_logloss: 0.502241
# [180]	valid_0's binary_logloss: 0.502146
# [181]	valid_0's binary_logloss: 0.502073
# [182]	valid_0's binary_logloss: 0.502003
# [183]	valid_0's binary_logloss: 0.501937
# [184]	valid_0's binary_logloss: 0.501873
# [185]	valid_0's binary_logloss: 0.501803
# [186]	valid_0's binary_logloss: 0.501738
# [187]	valid_0's binary_logloss: 0.501652
# [188]	valid_0's binary_logloss: 0.501509
# [189]	valid_0's binary_logloss: 0.501436
# [190]	valid_0's binary_logloss: 0.501385
# [191]	valid_0's binary_logloss: 0.501301
# [192]	valid_0's binary_logloss: 0.501242
# [193]	valid_0's binary_logloss: 0.501146
# [194]	valid_0's binary_logloss: 0.501022
# [195]	valid_0's binary_logloss: 0.500957
# [196]	valid_0's binary_logloss: 0.500842
# [197]	valid_0's binary_logloss: 0.500801
# [198]	valid_0's binary_logloss: 0.500716
# [199]	valid_0's binary_logloss: 0.500632
# [200]	valid_0's binary_logloss: 0.500551
# [201]	valid_0's binary_logloss: 0.500457
# [202]	valid_0's binary_logloss: 0.50042
# [203]	valid_0's binary_logloss: 0.500381
# [204]	valid_0's binary_logloss: 0.500286
# [205]	valid_0's binary_logloss: 0.500203
# [206]	valid_0's binary_logloss: 0.500146
# [207]	valid_0's binary_logloss: 0.500071
# [208]	valid_0's binary_logloss: 0.500029
# [209]	valid_0's binary_logloss: 0.499974
# [210]	valid_0's binary_logloss: 0.4999
# [211]	valid_0's binary_logloss: 0.499847
# [212]	valid_0's binary_logloss: 0.499804
# [213]	valid_0's binary_logloss: 0.499757
# [214]	valid_0's binary_logloss: 0.49971
# [215]	valid_0's binary_logloss: 0.499655
# [216]	valid_0's binary_logloss: 0.499639
# [217]	valid_0's binary_logloss: 0.499591
# [218]	valid_0's binary_logloss: 0.499522
# [219]	valid_0's binary_logloss: 0.499492
# LGBMClassifier(class_weight='balanced', eval_metric='auc',
#                learning_rate=0.01629792783423414, max_depth=6,
#                min_child_samples=79, n_estimators=219, num_leaves=44,
#                random_state=12)

# %%
os.makedirs(os.path.join('..', 'models', 'predictors'), exist_ok=True)

pickle.dump(
    model, 
    open(os.path.join('..', 'models', 'predictors', 'model.pkl'), 'wb')
)
