# %%
import os
import pandas as pd
import yaml
import pickle

from utils.training_utils import find_specific_variables

from lightgbm import LGBMClassifier

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
features = yaml.safe_load(open(os.path.join('..', 'src', 'config', 'feature_config.yaml'), 'r'))

# %% [markdown]
# # Modelo para classificação de um produto em promoção

# %%
df = pd.read_csv(os.path.join('..', 'data', 'train_test', 'train_encoded.csv'))

print(df.shape)
df.head()
# Out:
# (32940, 19)
#    contact  default  employment_status  job  month  poutcome  quarter   age  \
# 0      0.0      0.0                0.0  0.0    9.0       1.0      2.0  31.0
# 1      1.0      0.0                0.0  3.0    6.0       1.0      1.0  39.0
# 2      0.0      0.0                0.0  2.0    3.0       1.0      2.0  34.0
# 3      1.0      1.0                0.0  9.0    6.0       1.0      1.0  36.0
# 4      0.0      1.0                1.0  8.0    1.0       1.0      2.0  25.0
#
#    campaign  cons.conf.idx  cons.price.idx  contacts_tendency  emp.var.rate  \
# 0       3.0          -29.8          92.379                0.0          -3.4
# 1       2.0          -36.4          93.994                0.0           1.1
# 2       4.0          -42.7          93.918                0.0           1.4
# 3       9.0          -36.4          93.994                0.0           1.1
# 4       1.0          -31.4          92.201                0.0          -2.9
#
#    euribor3m  nr.employed  pdays  previous  was_contacted_before  y
# 0      0.803       5017.5  999.0       0.0                   0.0  0
# 1      4.857       5191.0  999.0       0.0                   0.0  0
# 2      4.958       5228.1  999.0       0.0                   0.0  0
# 3      4.856       5191.0  999.0       0.0                   0.0  0
# 4      0.825       5076.2  999.0       0.0                   0.0  0

# %%
seletor = pickle.load(
    open(os.path.join('..', 'models', 'encoders', 'seletor_2.pkl'), 'rb')
)

df_hyperparams = pickle.load(
    open(os.path.join('..', 'models', 'df_metrics_results_tunning_lgbm.pkl'), 'rb')
)

# %%
feature_target = find_specific_variables(features, 'target', specific_value=True)

# %%
df_treino, df_valid = train_test_split(df, test_size=0.2, random_state=96)

# %%
print(f'Shape Treino: {df_treino.shape}')
print(f'Shape Valid: {df_valid.shape}')
# Out:
# Shape Treino: (26352, 19)
# Shape Valid: (6588, 19)

# %%
print(f'% Treino: {df_treino[feature_target[0]].mean()}')
print(f'% Valid: {df_valid[feature_target[0]].mean()}')
# Out:
# % Treino: 0.11202185792349727
# % Valid: 0.11262902246508803

# %%
df_hyperparams[df_hyperparams.value == max(df_hyperparams.value)].T
# Out:
#                                                   23
# number                                            23
# value                                       0.806648
# datetime_start            2025-04-02 09:25:33.723947
# datetime_complete         2025-04-02 09:25:34.233851
# duration                      0 days 00:00:00.509904
# params_class_weight                             None
# params_learning_rate                          0.0466
# params_max_depth                                   5
# params_min_child_samples                          24
# params_n_estimators                              168
# params_num_leaves                                 44
# state                                       COMPLETE

# %%
best_row = df_hyperparams.loc[df_hyperparams['value'].idxmax()]
best_params = best_row.filter(like='params_')
hyper_params = {col.replace('params_', ''): best_params[col] for col in best_params.index}


hyper_params.update({
    'eval_metric': 'auc',
})

# %%
hyper_params
# Out:
# {'class_weight': None,
#  'learning_rate': 0.04659996319610005,
#  'max_depth': 5,
#  'min_child_samples': 24,
#  'n_estimators': 168,
#  'num_leaves': 44,
#  'eval_metric': 'auc'}

# %%
model = LGBMClassifier(
    **hyper_params,
    random_state=12,
    n_jobs=-1
)

model
# Out:
# LGBMClassifier(eval_metric='auc', learning_rate=0.04659996319610005,
#                max_depth=5, min_child_samples=24, n_estimators=168,
#                num_leaves=44, random_state=12)

# %%
model.fit(
    df_treino[seletor.features].values,
    df_treino[feature_target].values,
    eval_set=[(df_valid[seletor.features].values, df_valid[feature_target].values)],
    verbose=True
)
# Out:
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [1]	valid_0's binary_logloss: 0.341069
# [2]	valid_0's binary_logloss: 0.332616
# [3]	valid_0's binary_logloss: 0.325654
# [4]	valid_0's binary_logloss: 0.319922
# [5]	valid_0's binary_logloss: 0.315021
# [6]	valid_0's binary_logloss: 0.310718
# [7]	valid_0's binary_logloss: 0.306942
# [8]	valid_0's binary_logloss: 0.303645
# [9]	valid_0's binary_logloss: 0.300577
# [10]	valid_0's binary_logloss: 0.297876
# [11]	valid_0's binary_logloss: 0.295429
# [12]	valid_0's binary_logloss: 0.293168
# [13]	valid_0's binary_logloss: 0.291227
# [14]	valid_0's binary_logloss: 0.28943
# [15]	valid_0's binary_logloss: 0.28776
# [16]	valid_0's binary_logloss: 0.286268
# [17]	valid_0's binary_logloss: 0.284948
# [18]	valid_0's binary_logloss: 0.283728
# [19]	valid_0's binary_logloss: 0.28259
# [20]	valid_0's binary_logloss: 0.281516
# [21]	valid_0's binary_logloss: 0.280562
# [22]	valid_0's binary_logloss: 0.27973
# [23]	valid_0's binary_logloss: 0.278963
# [24]	valid_0's binary_logloss: 0.278256
# [25]	valid_0's binary_logloss: 0.277594
# [26]	valid_0's binary_logloss: 0.276909
# [27]	valid_0's binary_logloss: 0.276312
# [28]	valid_0's binary_logloss: 0.275766
# [29]	valid_0's binary_logloss: 0.275293
# [30]	valid_0's binary_logloss: 0.274853
# [31]	valid_0's binary_logloss: 0.274469
# [32]	valid_0's binary_logloss: 0.274097
# [33]	valid_0's binary_logloss: 0.273712
# [34]	valid_0's binary_logloss: 0.273405
# [35]	valid_0's binary_logloss: 0.27307
# [36]	valid_0's binary_logloss: 0.272785
# [37]	valid_0's binary_logloss: 0.272468
# [38]	valid_0's binary_logloss: 0.272238
# [39]	valid_0's binary_logloss: 0.272003
# [40]	valid_0's binary_logloss: 0.271777
# [41]	valid_0's binary_logloss: 0.271594
# [42]	valid_0's binary_logloss: 0.271448
# [43]	valid_0's binary_logloss: 0.271264
# [44]	valid_0's binary_logloss: 0.271054
# [45]	valid_0's binary_logloss: 0.270922
# [46]	valid_0's binary_logloss: 0.27077
# [47]	valid_0's binary_logloss: 0.270644
# [48]	valid_0's binary_logloss: 0.270528
# [49]	valid_0's binary_logloss: 0.270291
# [50]	valid_0's binary_logloss: 0.270154
# [51]	valid_0's binary_logloss: 0.269997
# [52]	valid_0's binary_logloss: 0.269811
# [53]	valid_0's binary_logloss: 0.269707
# [54]	valid_0's binary_logloss: 0.269622
# [55]	valid_0's binary_logloss: 0.269503
# [56]	valid_0's binary_logloss: 0.26939
# [57]	valid_0's binary_logloss: 0.269278
# [58]	valid_0's binary_logloss: 0.269184
# [59]	valid_0's binary_logloss: 0.26911
# [60]	valid_0's binary_logloss: 0.269032
# [61]	valid_0's binary_logloss: 0.268916
# [62]	valid_0's binary_logloss: 0.268833
# [63]	valid_0's binary_logloss: 0.268766
# [64]	valid_0's binary_logloss: 0.268707
# [65]	valid_0's binary_logloss: 0.268611
# [66]	valid_0's binary_logloss: 0.268522
# [67]	valid_0's binary_logloss: 0.268446
# [68]	valid_0's binary_logloss: 0.268336
# [69]	valid_0's binary_logloss: 0.268323
# [70]	valid_0's binary_logloss: 0.268277
# [71]	valid_0's binary_logloss: 0.26823
# [72]	valid_0's binary_logloss: 0.268234
# [73]	valid_0's binary_logloss: 0.268184
# [74]	valid_0's binary_logloss: 0.268207
# [75]	valid_0's binary_logloss: 0.268153
# [76]	valid_0's binary_logloss: 0.268108
# [77]	valid_0's binary_logloss: 0.26807
# [78]	valid_0's binary_logloss: 0.268054
# [79]	valid_0's binary_logloss: 0.268077
# [80]	valid_0's binary_logloss: 0.26805
# [81]	valid_0's binary_logloss: 0.268035
# [82]	valid_0's binary_logloss: 0.268002
# [83]	valid_0's binary_logloss: 0.268025
# [84]	valid_0's binary_logloss: 0.26801
# [85]	valid_0's binary_logloss: 0.268038
# [86]	valid_0's binary_logloss: 0.268028
# [87]	valid_0's binary_logloss: 0.26805
# [88]	valid_0's binary_logloss: 0.268048
# [89]	valid_0's binary_logloss: 0.268063
# [90]	valid_0's binary_logloss: 0.268046
# [91]	valid_0's binary_logloss: 0.268106
# [92]	valid_0's binary_logloss: 0.268128
# [93]	valid_0's binary_logloss: 0.268108
# [94]	valid_0's binary_logloss: 0.268123
# [95]	valid_0's binary_logloss: 0.26814
# [96]	valid_0's binary_logloss: 0.268098
# [97]	valid_0's binary_logloss: 0.268082
# [98]	valid_0's binary_logloss: 0.268017
# [99]	valid_0's binary_logloss: 0.268026
# [100]	valid_0's binary_logloss: 0.267967
# [101]	valid_0's binary_logloss: 0.267999
# [102]	valid_0's binary_logloss: 0.267992
# [103]	valid_0's binary_logloss: 0.268005
# [104]	valid_0's binary_logloss: 0.268002
# [105]	valid_0's binary_logloss: 0.267958
# [106]	valid_0's binary_logloss: 0.267938
# [107]	valid_0's binary_logloss: 0.267922
# [108]	valid_0's binary_logloss: 0.267892
# [109]	valid_0's binary_logloss: 0.267937
# [110]	valid_0's binary_logloss: 0.267939
# [111]	valid_0's binary_logloss: 0.267946
# [112]	valid_0's binary_logloss: 0.267946
# [113]	valid_0's binary_logloss: 0.267978
# [114]	valid_0's binary_logloss: 0.267943
# [115]	valid_0's binary_logloss: 0.26795
# [116]	valid_0's binary_logloss: 0.267956
# [117]	valid_0's binary_logloss: 0.267969
# [118]	valid_0's binary_logloss: 0.267952
# [119]	valid_0's binary_logloss: 0.267952
# [120]	valid_0's binary_logloss: 0.267976
# [121]	valid_0's binary_logloss: 0.268001
# [122]	valid_0's binary_logloss: 0.267971
# [123]	valid_0's binary_logloss: 0.267967
# [124]	valid_0's binary_logloss: 0.267981
# [125]	valid_0's binary_logloss: 0.267972
# [126]	valid_0's binary_logloss: 0.267951
# [127]	valid_0's binary_logloss: 0.267961
# [128]	valid_0's binary_logloss: 0.267975
# [129]	valid_0's binary_logloss: 0.267988
# [130]	valid_0's binary_logloss: 0.267941
# [131]	valid_0's binary_logloss: 0.267955
# [132]	valid_0's binary_logloss: 0.267935
# [133]	valid_0's binary_logloss: 0.267937
# [134]	valid_0's binary_logloss: 0.267949
# [135]	valid_0's binary_logloss: 0.267943
# [136]	valid_0's binary_logloss: 0.267903
# [137]	valid_0's binary_logloss: 0.267885
# [138]	valid_0's binary_logloss: 0.26785
# [139]	valid_0's binary_logloss: 0.267807
# [140]	valid_0's binary_logloss: 0.267831
# [141]	valid_0's binary_logloss: 0.267883
# [142]	valid_0's binary_logloss: 0.267868
# [143]	valid_0's binary_logloss: 0.267859
# [144]	valid_0's binary_logloss: 0.267871
# [145]	valid_0's binary_logloss: 0.267886
# [146]	valid_0's binary_logloss: 0.267868
# [147]	valid_0's binary_logloss: 0.267826
# [148]	valid_0's binary_logloss: 0.267828
# [149]	valid_0's binary_logloss: 0.267853
# [150]	valid_0's binary_logloss: 0.267834
# [151]	valid_0's binary_logloss: 0.26778
# [152]	valid_0's binary_logloss: 0.267756
# [153]	valid_0's binary_logloss: 0.267797
# [154]	valid_0's binary_logloss: 0.267856
# [155]	valid_0's binary_logloss: 0.267863
# [156]	valid_0's binary_logloss: 0.267841
# [157]	valid_0's binary_logloss: 0.267832
# [158]	valid_0's binary_logloss: 0.267835
# [159]	valid_0's binary_logloss: 0.267844
# [160]	valid_0's binary_logloss: 0.267831
# [161]	valid_0's binary_logloss: 0.267824
# [162]	valid_0's binary_logloss: 0.267817
# [163]	valid_0's binary_logloss: 0.267794
# [164]	valid_0's binary_logloss: 0.267786
# [165]	valid_0's binary_logloss: 0.267788
# [166]	valid_0's binary_logloss: 0.267849
# [167]	valid_0's binary_logloss: 0.267883
# [168]	valid_0's binary_logloss: 0.267869
# LGBMClassifier(eval_metric='auc', learning_rate=0.04659996319610005,
#                max_depth=5, min_child_samples=24, n_estimators=168,
#                num_leaves=44, random_state=12)

# %%
pickle.dump(
    model, 
    open(os.path.join('..', 'models', 'predictors', 'model.pkl'), 'wb')
)
